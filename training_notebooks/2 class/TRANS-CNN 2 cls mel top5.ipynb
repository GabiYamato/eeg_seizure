# %% [markdown]
# <div style="background: linear-gradient(to right,rgb(225, 231, 134),rgb(176, 238, 148),rgb(150, 232, 238)); padding: 20px; border-radius: 10px; text-align: center; box-shadow: 0 10px 20px rgba(0,0,0,0.19), 0 6px 6px rgba(0,0,0,0.23);">
#     <span style="font-family: 'Montserrat', sans-serif; font-weight: 800; font-size: 2.5em; color: white; text-shadow: 2px 2px 4px #000;">✨ 2 CLASS CLASSIFICATION MANUAL AND CLASS WEIGHTS STRATEGY✨</span>
# </div>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GroupKFold
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import precision_score, recall_score, f1_score, balanced_accuracy_score
import pickle
from collections import defaultdict
from sklearn.utils import shuffle
import os
import cv2
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import pandas as pd

from torchinfo import summary
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# <div style="background: linear-gradient(to right,rgb(225, 231, 134),rgb(176, 238, 148),rgb(150, 232, 238)); padding: 20px; border-radius: 10px; text-align: center; box-shadow: 0 10px 20px rgba(0,0,0,0.19), 0 6px 6px rgba(0,0,0,0.23);">
#     <span style="font-family: 'Montserrat', sans-serif; font-weight: 800; font-size: 2.5em; color: white; text-shadow: 2px 2px 4px #000;">✨ LOADING THE SPLIT DATA ARRAYS ✨</span>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right,rgb(225, 231, 134),rgb(176, 238, 148),rgb(150, 232, 238)); padding: 15px; border-radius: 8px; text-align: center; box-shadow: 0 8px 16px rgba(0,0,0,0.19), 0 4px 4px rgba(0,0,0,0.23);">
#     <span style="font-family: 'Montserrat', sans-serif; font-weight: 700; font-size: 1.2em; color: white; text-shadow: 1px 1px 3px #000;">📁 reminder to change the folder path to your numpy array folder 📁</span>
# </div>

# %%
import numpy as np
import os

# Define the folder path
folder_path = r"D:\PYTHONIG\newwindow\NOTEBOOKS_2025\aprilmay2025\data\numpy\melnormalized\concatenatedspectrograms"

# Load the numpy files into the respective arrays with the correct capitalized naming
eeg_fold_1 = np.load(os.path.join(folder_path, 'MEL_DATA_FOLD_fold_1.npy'))
labels_fold_1 = np.load(os.path.join(folder_path, 'MEL_LABELS_FOLD_fold_1.npy'))
patients_fold_1 = np.load(os.path.join(folder_path, 'MEL_PATIENTS_FOLD_fold_1.npy'))

eeg_fold_2 = np.load(os.path.join(folder_path, 'MEL_DATA_FOLD_fold_2.npy'))
labels_fold_2 = np.load(os.path.join(folder_path, 'MEL_LABELS_FOLD_fold_2.npy'))
patients_fold_2 = np.load(os.path.join(folder_path, 'MEL_PATIENTS_FOLD_fold_2.npy'))

eeg_fold_3 = np.load(os.path.join(folder_path, 'MEL_DATA_FOLD_fold_3.npy'))
labels_fold_3 = np.load(os.path.join(folder_path, 'MEL_LABELS_FOLD_fold_3.npy'))
patients_fold_3 = np.load(os.path.join(folder_path, 'MEL_PATIENTS_FOLD_fold_3.npy'))

eeg_fold_4 = np.load(os.path.join(folder_path, 'MEL_DATA_FOLD_fold_4.npy'))
labels_fold_4 = np.load(os.path.join(folder_path, 'MEL_LABELS_FOLD_fold_4.npy'))
patients_fold_4 = np.load(os.path.join(folder_path, 'MEL_PATIENTS_FOLD_fold_4.npy'))

eeg_fold_5 = np.load(os.path.join(folder_path, 'MEL_DATA_FOLD_fold_5.npy'))
labels_fold_5 = np.load(os.path.join(folder_path, 'MEL_LABELS_FOLD_fold_5.npy'))
patients_fold_5 = np.load(os.path.join(folder_path, 'MEL_PATIENTS_FOLD_fold_5.npy'))

eeg_folds = [eeg_fold_1, eeg_fold_2, eeg_fold_3, eeg_fold_4, eeg_fold_5]
labels_folds = [labels_fold_1, labels_fold_2, labels_fold_3, labels_fold_4, labels_fold_5]
patients_folds = [patients_fold_1, patients_fold_2, patients_fold_3, patients_fold_4, patients_fold_5]

for i in range(len(eeg_folds)):
    eeg_folds[i] = eeg_folds[i].astype(np.float16)

# %% [markdown]
# <div style="background: linear-gradient(to right,rgb(225, 231, 134),rgb(176, 238, 148),rgb(150, 232, 238)); padding: 15px; border-radius: 8px; text-align: center; box-shadow: 0 8px 16px rgba(0,0,0,0.19), 0 4px 4px rgba(0,0,0,0.23);">
#     <span style="font-family: 'Montserrat', sans-serif; font-weight: 700; font-size: 1.2em; color: white; text-shadow: 1px 1px 3px #000;">converting to 2 class</span>
# </div>

# %%
for i in range (len(labels_fold_1)):
    if (labels_fold_1[i] == 2):
        labels_fold_1[i] = 1

for i in range (len(labels_fold_2)):
    if (labels_fold_2[i] == 2):
        labels_fold_2[i] = 1

for i in range (len(labels_fold_3)):
    if (labels_fold_3[i] == 2):
        labels_fold_3[i] = 1

for i in range (len(labels_fold_4)):
    if (labels_fold_4[i] == 2):
        labels_fold_4[i] = 1

for i in range (len(labels_fold_5)):
    if (labels_fold_5[i] == 2):
        labels_fold_5[i] = 1

# %% [markdown]
# <div style="background: linear-gradient(to right,rgb(225, 231, 134),rgb(176, 238, 148),rgb(150, 232, 238)); padding: 15px; border-radius: 8px; text-align: center; box-shadow: 0 8px 16px rgba(0,0,0,0.19), 0 4px 4px rgba(0,0,0,0.23);">
#     <span style="font-family: 'Montserrat', sans-serif; font-weight: 700; font-size: 1.2em; color: white; text-shadow: 1px 1px 3px #000;">data balancer & early stopping</span>
# </div>

# %%
def data_balancer(data, labels, factor):
    # Count the number of samples in each class
    num_class_0 = np.sum(labels == 0)
    num_class_1 = np.sum(labels == 1)


    # Find the minimum number of samples across all classes
    min_samples = min(num_class_0, num_class_1)

    # Calculate the number of samples to take from each class
    samples_per_class = min_samples // factor

    # Randomly sample 'samples_per_class' from each class
    class_0_indices = np.random.choice(np.where(labels == 0)[0], samples_per_class, replace=False)
    class_1_indices = np.random.choice(np.where(labels == 1)[0], samples_per_class, replace=False)


    # Combine balanced indices
    balanced_indices = np.concatenate((class_0_indices, class_1_indices))

    # Shuffle the balanced indices
    np.random.shuffle(balanced_indices)

    # Create balanced training data and labels
    balanced_data = data[balanced_indices]
    balanced_labels = labels[balanced_indices]

    return balanced_data, balanced_labels

# %%
class EarlyStopping:
    def __init__(self, patience=5):
        """
        Initializes the early stopping mechanism based on divergence detection.

        Args:
            patience (int): Number of consecutive epochs with increasing validation loss
                            before stopping.
        """
        self.patience = patience
        self.best_loss = None
        self.counter = 0
        self.early_stop = False
        self.best_model_state = None

    def __call__(self, val_loss, model):
        """
        Checks if the validation loss is diverging and updates the state accordingly.

        Args:
            val_loss (float): Current epoch's validation loss.
            model (torch.nn.Module): The model being trained.
        """
        if self.best_loss is None or val_loss < self.best_loss:
            # Improvement detected
            self.best_loss = val_loss
            self.best_model_state = model.state_dict()
            self.counter = 0
        else:
            # Validation loss increased
            self.counter += 1
            if self.counter >= self.patience:
                print(f"Divergence detected. Stopping training after {self.counter} epochs.")
                self.early_stop = True

    def load_best_model(self, model):
        """
        Restores the model to the state with the lowest validation loss.

        Args:
            model (torch.nn.Module): The model to restore.
        """
        model.load_state_dict(self.best_model_state)

# %% [markdown]
# <div style="background: linear-gradient(to right,rgb(225, 231, 134),rgb(176, 238, 148),rgb(150, 232, 238)); padding: 15px; border-radius: 8px; text-align: center; box-shadow: 0 8px 16px rgba(0,0,0,0.19), 0 4px 4px rgba(0,0,0,0.23);">
#     <span style="font-family: 'Montserrat', sans-serif; font-weight: 700; font-size: 1.2em; color: white; text-shadow: 1px 1px 3px #000;">Result plotting</span>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    confusion_matrix,
    precision_recall_curve,
    roc_curve,
    auc,
    f1_score,
    balanced_accuracy_score,
    classification_report,
)
from sklearn.preprocessing import label_binarize

def plot_metrics(labels, predictions, n_classes=2):
    """
    Computes and visualizes classification metrics.

    Args:
        labels (array-like): True class labels.
        predictions (array-like): Probabilities or class predictions.
        n_classes (int): Number of classes (default: 2 for binary classification).
    """
    
    # Convert probability predictions to class labels if needed
    if predictions.ndim > 1:
        predicted_classes = np.argmax(predictions, axis=1)
    else:
        predicted_classes = predictions

    # Compute Confusion Matrix
    cm = confusion_matrix(labels, predicted_classes)
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', cbar=False)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

    # Class-wise Accuracy
    print("\nClass-wise Accuracy:")
    class_accuracies = []
    for d in range(n_classes):
        correct_preds = cm[d][d]
        total_true_samples = sum(cm[d])
        accuracy = correct_preds / total_true_samples if total_true_samples > 0 else 0
        class_accuracies.append(accuracy)
        print(f'Class {d}: {correct_preds}/{total_true_samples} ({accuracy:.2%})')

    # Precision-Recall Curve & AUPRC
    print("\nPrecision-Recall Curve:")
    plt.figure()
    
    if n_classes == 2:
        # Binary classification
        precision, recall, _ = precision_recall_curve(labels, predictions[:, 1])
        auprc = auc(recall, precision)
        plt.plot(recall, precision, label=f'AUPRC = {auprc:.2f}')
        avg_auprc = auprc
    else:
        # Multi-class case
        labels_binarized = label_binarize(labels, classes=np.arange(n_classes))
        auprcs = []
        for class_idx in range(n_classes):
            precision, recall, _ = precision_recall_curve(labels_binarized[:, class_idx], predictions[:, class_idx])
            auprc = auc(recall, precision)
            auprcs.append(auprc)
            plt.plot(recall, precision, label=f'Class {class_idx} (AUPRC = {auprc:.2f})')
        avg_auprc = np.mean(auprcs)

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.legend()
    plt.grid(True)
    plt.show()

    # ROC Curve & AUC
    print("\nROC Curve:")
    plt.figure()
    
    if n_classes == 2:
        # Binary classification
        fpr, tpr, _ = roc_curve(labels, predictions[:, 1])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'AUC = {roc_auc:.2f}')
    else:
        # Multi-class case
        for class_idx in range(n_classes):
            fpr, tpr, _ = roc_curve(labels_binarized[:, class_idx], predictions[:, class_idx])
            roc_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, label=f'Class {class_idx} (AUC = {roc_auc:.2f})')

    plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Compute Metrics
    f1 = f1_score(labels, predicted_classes, average='macro')
    balanced_acc = balanced_accuracy_score(labels, predicted_classes)

    print(f"\nMean F1 Score: {f1:.4f}")
    print(f"Balanced Accuracy: {balanced_acc:.4f}")
    print(f"Average AUPRC: {avg_auprc:.4f}")

    print("\nClassification Report:")
    print(classification_report(labels, predicted_classes))

    return {
        "confusion_matrix": cm,
        "class_wise_accuracy": class_accuracies,
        "mean_f1_score": f1,
        "balanced_accuracy": balanced_acc,
    }

# %% [markdown]
# <div style="background: linear-gradient(to right,rgb(225, 231, 134),rgb(238, 206, 148),rgb(238, 150, 150)); padding: 15px; border-radius: 8px; text-align: center; box-shadow: 0 8px 16px rgba(0,0,0,0.19), 0 4px 4px rgba(0,0,0,0.23);">
#     <span style="font-family: 'Montserrat', sans-serif; font-weight: 700; font-size: 1.2em; color: white; text-shadow: 1px 1px 3px #000;">MODEL GOES HERE</span>
# </div>

# %%
import torch
import torch.nn as nn

class CustomCnn(nn.Module):
    def __init__(self, debug_mode_flag=False):
        super().__init__()
        self.debug_mode_flag = debug_mode_flag
        
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)  # Reduces spatial size
        )
        
        self.block_2 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)  # Further reduces spatial size
        )

        # Global Average Pooling to reduce spatial dimensions 
        self.global_avg_pool = nn.AdaptiveAvgPool2d((8, 8))  # Keeps a manageable seq_len
        self.flatten = nn.Flatten(start_dim=2)  # Keeps batch & channel dims

    def forward(self, x):
        if self.debug_mode_flag: print(f"Input shape: {x.shape}")
        
        x = self.block_1(x)
        if self.debug_mode_flag: print(f"Block 1 shape: {x.shape}")
        
        x = self.block_2(x)
        if self.debug_mode_flag: print(f"Block 2 shape: {x.shape}")
        
        x = self.global_avg_pool(x)  # (batch, 128, 8, 8)
        if self.debug_mode_flag: print(f"Global Avg Pool shape: {x.shape}")

        # x = self.flatten(x)  # (batch, 128, 64)
        # if self.debug_mode_flag: print(f"Flattened shape (Transformer Input): {x.shape}")
        
        return x

    
class TransformerEncoder(nn.Module):
    def __init__(self, embed_dim, num_heads, ff_dim, dropout_rate=0.1):
        super(TransformerEncoder, self).__init__()
        self.att = nn.MultiheadAttention(embed_dim=embed_dim, num_heads=num_heads)
        self.ffn = nn.Sequential(
            nn.Linear(embed_dim, ff_dim),
            nn.ReLU(),
            nn.Linear(ff_dim, embed_dim)
        )
        self.layernorm1 = nn.LayerNorm(embed_dim)
        self.layernorm2 = nn.LayerNorm(embed_dim)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.dropout2 = nn.Dropout(dropout_rate)

    def forward(self, x):
        attn_output, _ = self.att(x, x, x)
        attn_output = self.dropout1(attn_output)
        out1 = self.layernorm1(x + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output)
        return self.layernorm2(out1 + ffn_output)

debug_mode_flag = False
class TRANS_CNN(nn.Module):
    def __init__(self, input_shape, num_classes, embed_dim=512, num_heads=2, ff_dim=64, num_transformer_blocks=4):
        
        super(TRANS_CNN,self).__init__()
        
        self.num_transformer_blocks = num_transformer_blocks
        self.cnn_extractor = CustomCnn()
        
        self.projection = nn.Linear(512, embed_dim)
        
        self.encoder = nn.ModuleList([
            TransformerEncoder(embed_dim,num_heads,ff_dim) for _ in range(num_transformer_blocks)
        ])
        
        self.global_avg_pool = nn.AdaptiveAvgPool1d(1)
        self.dropout = nn.Dropout(0.1)
        
        self.precls = nn.Linear(embed_dim,embed_dim)
        self.precls2 = nn.Linear(embed_dim,embed_dim)
        self.precls3 = nn.Linear(embed_dim,embed_dim//4)
        
        self.clf = nn.Linear(embed_dim//4,num_classes)
        
        
    def forward(self,x):
        
        x = self.cnn_extractor(x)
        if debug_mode_flag: print(f"x shape after cnn extraction = {x.shape}")
        
        B,C,H,W = x.shape
        
        x = x.view(B,H*W,C)
        if debug_mode_flag: print(f"x shape after changing view= {x.shape}")
        
        # x = self.projection(x)
        # if debug_mode_flag: print(f"x shape after projection= {x.shape}")
        
        for encoderblock in self.encoder:
            x = encoderblock(x)
            
        if debug_mode_flag: print(f"x shape after passing thru encoder= {x.shape}")
        
        x = x.permute(1,0,2)
        if debug_mode_flag: print(f"x shape after permuting{x.shape}")
        
        x = self.precls3(x)
        if debug_mode_flag: print(f"precls3 {x.shape}")
        
        x = self.dropout(x)
        
        x = x.mean(dim=0)  # Global average pooling over sequence (9 tokens → 1 token)
        if debug_mode_flag: print(f"x shape after average pooling {x.shape}")

        x = self.clf(x)  #they see me rolling
        if debug_mode_flag: print(f"cls {x.shape}")
        
        
        return x

# %% [markdown]
# <div style="background: linear-gradient(to right,rgb(225, 231, 134),rgb(238, 206, 148),rgb(238, 150, 150)); padding: 15px; border-radius: 8px; text-align: center; box-shadow: 0 8px 16px rgba(0,0,0,0.19), 0 4px 4px rgba(0,0,0,0.23);">
#     <span style="font-family: 'Montserrat', sans-serif; font-weight: 700; font-size: 1.2em; color: white; text-shadow: 1px 1px 3px #000;">Test with demo data & model Summary</span>
# </div>

# %%
model  = TRANS_CNN(input_shape=(3,224,224),num_classes=2,num_transformer_blocks=4,embed_dim=128) # declare model here
randomdata = torch.randn((1,3,224,224))
output = model(randomdata)
output.shape
# Out:
# torch.Size([1, 2])

# %%
from torchinfo import summary

summary(model)
# Out:
# =====================================================================================
# Layer (type:depth-idx)                                       Param #
# =====================================================================================
# TRANS_CNN                                                    --
# ├─CustomCnn: 1-1                                             --
# │    └─Sequential: 2-1                                       --
# │    │    └─Conv2d: 3-1                                      448
# │    │    └─BatchNorm2d: 3-2                                 32
# │    │    └─ReLU: 3-3                                        --
# │    │    └─Conv2d: 3-4                                      4,640
# │    │    └─BatchNorm2d: 3-5                                 64
# │    │    └─ReLU: 3-6                                        --
# │    │    └─MaxPool2d: 3-7                                   --
# │    └─Sequential: 2-2                                       --
# │    │    └─Conv2d: 3-8                                      18,496
# │    │    └─BatchNorm2d: 3-9                                 128
# │    │    └─ReLU: 3-10                                       --
# │    │    └─Conv2d: 3-11                                     73,856
# │    │    └─BatchNorm2d: 3-12                                256
# │    │    └─ReLU: 3-13                                       --
# │    │    └─MaxPool2d: 3-14                                  --
# │    └─AdaptiveAvgPool2d: 2-3                                --
# │    └─Flatten: 2-4                                          --
# ├─Linear: 1-2                                                65,664
# ├─ModuleList: 1-3                                            --
# │    └─TransformerEncoder: 2-5                               --
# │    │    └─MultiheadAttention: 3-15                         66,048
# │    │    └─Sequential: 3-16                                 16,576
# │    │    └─LayerNorm: 3-17                                  256
# │    │    └─LayerNorm: 3-18                                  256
# │    │    └─Dropout: 3-19                                    --
# │    │    └─Dropout: 3-20                                    --
# │    └─TransformerEncoder: 2-6                               --
# │    │    └─MultiheadAttention: 3-21                         66,048
# │    │    └─Sequential: 3-22                                 16,576
# │    │    └─LayerNorm: 3-23                                  256
# │    │    └─LayerNorm: 3-24                                  256
# │    │    └─Dropout: 3-25                                    --
# │    │    └─Dropout: 3-26                                    --
# │    └─TransformerEncoder: 2-7                               --
# │    │    └─MultiheadAttention: 3-27                         66,048
# │    │    └─Sequential: 3-28                                 16,576
# │    │    └─LayerNorm: 3-29                                  256
# │    │    └─LayerNorm: 3-30                                  256
# │    │    └─Dropout: 3-31                                    --
# │    │    └─Dropout: 3-32                                    --
# │    └─TransformerEncoder: 2-8                               --
# │    │    └─MultiheadAttention: 3-33                         66,048
# │    │    └─Sequential: 3-34                                 16,576
# │    │    └─LayerNorm: 3-35                                  256
# │    │    └─LayerNorm: 3-36                                  256
# │    │    └─Dropout: 3-37                                    --
# │    │    └─Dropout: 3-38                                    --
# ├─AdaptiveAvgPool1d: 1-4                                     --
# ├─Dropout: 1-5                                               --
# ├─Linear: 1-6                                                16,512
# ├─Linear: 1-7                                                16,512
# ├─Linear: 1-8                                                4,128
# ├─Linear: 1-9                                                66
# =====================================================================================
# Total params: 533,346
# Trainable params: 533,346
# Non-trainable params: 0
# =====================================================================================

# %% [markdown]
# <div style="background: linear-gradient(to right,rgb(225, 231, 134),rgb(238, 206, 148),rgb(238, 150, 150)); padding: 15px; border-radius: 8px; text-align: center; box-shadow: 0 8px 16px rgba(0,0,0,0.19), 0 4px 4px rgba(0,0,0,0.23);">
#     <span style="font-family: 'Montserrat', sans-serif; font-weight: 700; font-size: 1.2em; color: white; text-shadow: 1px 1px 3px #000;">Training Code</span>
# </div>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import balanced_accuracy_score, confusion_matrix
from sklearn.preprocessing import label_binarize
from sklearn.metrics import precision_recall_curve, auc

# %%
import pandas as pd
import os
import datetime

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import balanced_accuracy_score, confusion_matrix
from sklearn.preprocessing import label_binarize
from sklearn.metrics import precision_recall_curve, auc


# Fold indices and other configurations
num_folds = 5
fold_indices = np.random.permutation(np.arange(num_folds))
val_fold_indices = np.roll(fold_indices, 1)

test_folds_chosen = []
val_folds_chosen = []
fold_confusion_matrices = []  # To store confusion matrices for each fold
fold_accuracies = []  # To store balanced accuracy for each fold
fold_auprcs = []  # To store AUPRC for each fold

# Model and training configurations
num_classes = 2
epochs = 100
input_shape = (3,224,224)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


torch.random.manual_seed(42)  # For reproducibility
np.random.seed(42)  # For reproducibility

all_params = [
    {
        "num_heads": 2,
        "num_transformer_blocks": 2,
        "learning_rate": 2.782228330205127e-05,
        "optimizer": "Adam",
        "weight_decay": 1.89223276202094e-06,
        "batch_size": 10,
        "label_smoothing": 0.17
    },  # Trial 86, Accuracy = 0.5554 
    {
        "num_heads": 2,
        "num_transformer_blocks": 4,
        "learning_rate": 1.2292958406478385e-05,
        "optimizer": "Adam",
        "weight_decay": 5.221031733062504e-06,
        "batch_size": 32,
        "label_smoothing": 0.16
    },  # Trial 69, Accuracy = 0.5460
    {
        "num_heads": 32,
        "num_transformer_blocks": 8,
        "learning_rate": 1.4338089312657102e-05,
        "optimizer": "Adam",
        "weight_decay": 0.0006154361290634533,
        "batch_size": 32,
        "label_smoothing": 0.17
    },  # Trial 48, Accuracy = 0.5408
    {
        "num_heads": 16,
        "num_transformer_blocks": 2,
        "learning_rate": 0.00012771315175564576,
        "optimizer": "Adam",
        "weight_decay": 1.3852738619108427e-06,
        "batch_size": 10,
        "label_smoothing": 0.14
    },  # Trial 133, Accuracy = 0.5405
    {
        "num_heads": 32,
        "num_transformer_blocks": 8,
        "learning_rate": 2.5198448093373934e-05,
        "optimizer": "Adam",
        "weight_decay": 0.0004641556896534395,
        "batch_size": 32,
        "label_smoothing": 0.16
    }  # Trial 53, Accuracy = 0.5403
]

p_indx = 1

for params in all_params:
    
    print("_"*50)
    print("_"*50)
    print("_"*50)
    print("params set:",p_indx)
    print("_"*50)
    print("_"*50)
    print("_"*50)
    
    num_heads = params["num_heads"]
    num_transformer_blocks = params["num_transformer_blocks"]
    learning_rate = params["learning_rate"]
    optimizer_name = params["optimizer"]
    weight_decay = params["weight_decay"]
    batch_size = params["batch_size"]
    label_smoothing = params["label_smoothing"]

    print(f"Running with params: {params}")
    
    def save_results_to_csv(fold_accuracies, fold_auprcs, fold_confusion_matrices, model_info, csv_path=r"G:\CODING\py\newnotebooks\results.csv"):
        """
        Save all results from the current experiment to a CSV file
        
        Parameters:
        - fold_accuracies: list of balanced accuracy scores for each fold
        - fold_auprcs: list of AUPRC scores for each fold
        - fold_confusion_matrices: list of confusion matrices for each fold
        - model_info: string with model architecture description
        - csv_path: path to the CSV file to save results
        """
        # Current time for experiment identification
        timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        
        # Prepare data for the DataFrame
        data = {
            "timestamp": timestamp,
            "model_info": model_info,
            "num_classes": num_classes,
            "learning_rate": learning_rate,
            "epochs": epochs,
            "mean_balanced_accuracy": np.mean(fold_accuracies),
            "std_balanced_accuracy": np.std(fold_accuracies),
            "mean_auprc": np.mean(fold_auprcs),
            "std_auprc": np.std(fold_auprcs),
        }
        
        # Add individual fold results
        for i, (acc, auprc) in enumerate(zip(fold_accuracies, fold_auprcs)):
            data[f"fold_{i+1}_accuracy"] = acc
            data[f"fold_{i+1}_auprc"] = auprc
        
        # Add confusion matrix info
        for i, cm in enumerate(fold_confusion_matrices):
            data[f"fold_{i+1}_confusion_matrix"] = str(cm)
        
        # Create DataFrame and append to CSV
        df = pd.DataFrame([data])
        
        # Check if file exists
        file_exists = os.path.isfile(csv_path)
        
        # Save to CSV
        if file_exists:
            df.to_csv(csv_path, mode='a', header=False, index=False)
        else:
            df.to_csv(csv_path, mode='w', header=True, index=False)

        print(f"Results saved to {csv_path}") 

    # Training loop for cross-validation
    for fold_idx in range(num_folds):
        print("_"*50)
        print("_"*50)
        print("_"*50)
        
        print(f'Fold No: {fold_idx + 1}')
        
        # Initialize model, loss, and optimizer
        fold_model = TRANS_CNN(input_shape=input_shape,num_classes=num_classes,embed_dim=128,num_heads=num_heads,num_transformer_blocks=num_transformer_blocks) # Initialize your model here
        fold_model.to(device)
        
        criterion = nn.CrossEntropyLoss(label_smoothing=0.3)
        
        optimizer = optim.Adam(fold_model.parameters(), lr=learning_rate,weight_decay=weight_decay)
        
        # Split data into train, validation, and test sets
        test_fold = fold_indices[fold_idx]
        val_fold = val_fold_indices[fold_idx]
        train_folds = [fold for fold in fold_indices if fold != test_fold and fold != val_fold]

        train_data = np.concatenate([eeg_folds[j] for j in train_folds])
        train_labels = np.concatenate([labels_folds[j] for j in train_folds])
        train_data = train_data.transpose(0, 3, 1, 2)  # Transpose to match PyTorch input format

        test_folds_chosen.append(test_fold)
        val_folds_chosen.append(val_fold)
        
        early_stopping = EarlyStopping(patience=10)
        
        # Training loop
        for epoch in range(epochs):
            balanced_train_data, balanced_train_labels = data_balancer(train_data, train_labels, factor=1)

            train_dataset = TensorDataset(
                torch.tensor(balanced_train_data, dtype=torch.float32).to(device),
                torch.tensor(balanced_train_labels, dtype=torch.long).to(device)
            )
            train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
            
            fold_model.train()
            running_loss = 0.0
            all_preds = []
            all_labels = []
            
            for inputs, labels in train_loader:
                optimizer.zero_grad()
                outputs = fold_model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                
                running_loss += loss.item()
                _, preds = torch.max(outputs, 1)
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
                
            epoch_loss = running_loss / len(train_loader)
            epoch_acc = balanced_accuracy_score(all_labels, all_preds)
            print(f'Epoch [{epoch + 1}/{epochs}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}')

            # Validation loop
            val_data = eeg_folds[val_fold].transpose(0, 3, 1, 2)
            val_labels = labels_folds[val_fold]
            val_dataset = TensorDataset(
                torch.tensor(val_data, dtype=torch.float32).to(device),
                torch.tensor(val_labels, dtype=torch.long).to(device)
            )
            val_loader = DataLoader(val_dataset, batch_size=10, shuffle=False)

            fold_model.eval()
            val_loss = 0.0
            val_preds = []
            val_labels_list = []

            with torch.no_grad():
                for val_inputs, val_labels in val_loader:
                    val_outputs = fold_model(val_inputs)
                    loss = criterion(val_outputs, val_labels)
                    val_loss += loss.item()

                    _, val_batch_preds = torch.max(val_outputs, 1)
                    val_preds.extend(val_batch_preds.cpu().numpy())
                    val_labels_list.extend(val_labels.cpu().numpy())

            val_loss /= len(val_loader)
            val_acc = balanced_accuracy_score(val_labels_list, val_preds)
            print(f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}')

            early_stopping(val_loss, fold_model)
            if early_stopping.early_stop:
                print("Early stopping")
                break

        # Load the best model
        early_stopping.load_best_model(fold_model)

        # Test loop
        test_data = eeg_folds[test_fold].transpose(0, 3, 1, 2)
        test_labels = labels_folds[test_fold]
        test_dataset = TensorDataset(
            torch.tensor(test_data, dtype=torch.float32).to(device),
            torch.tensor(test_labels, dtype=torch.long).to(device)
        )
        test_loader = DataLoader(test_dataset, batch_size=10, shuffle=False)

        fold_model.eval()
        test_probs = []
        test_preds = []
        test_labels_list = []

        with torch.no_grad():
            for test_inputs, test_labels in test_loader:
                test_outputs = fold_model(test_inputs)
                probabilities = torch.softmax(test_outputs, dim=1)
                test_probs.extend(probabilities.cpu().numpy())
                _, preds = torch.max(probabilities, 1)
                test_preds.extend(preds.cpu().numpy())
                test_labels_list.extend(test_labels.cpu().numpy())

        # Compute metrics
        test_acc = balanced_accuracy_score(test_labels_list, test_preds)
        fold_accuracies.append(test_acc)

        cm = confusion_matrix(test_labels_list, test_preds)
        fold_confusion_matrices.append(cm)

        test_labels_binarized = test_labels_list
        test_auprcs = []

        precision, recall, _ = precision_recall_curve(test_labels_list, np.array(test_probs)[:, 1])
        auprc = auc(recall, precision)
        test_auprcs.append(auprc)

        mean_test_auprc = np.mean(test_auprcs)
        fold_auprcs.append(mean_test_auprc)

        print(f'Test Fold {fold_idx + 1}, Mean AUPRC: {mean_test_auprc:.4f}, Balanced Accuracy: {test_acc:.4f}')

        # Use the plot_metrics function to visualize metrics
        plot_metrics(np.array(test_labels_list), np.array(test_probs), n_classes=num_classes)

    # Final metrics across all folds
    average_auprc = np.mean(fold_auprcs)
    mean_accuracy = np.mean(fold_accuracies)
    print(f'Accuracy for each fold: {fold_accuracies}')
    print(f'AUPRC for each fold: {fold_auprcs}')
    print(f'Average AUPRC across all folds: {average_auprc}')
    print(f'Average Balanced Accuracy across all folds: {mean_accuracy}')
        
    # Save all results to CSV
    model_description = f"TRANS_CNN {p_indx} MANUAL APPROACH 2 CLASS"
    save_results_to_csv(fold_accuracies, fold_auprcs, fold_confusion_matrices, model_description,csv_path=r"D:\PYTHONIG\newwindow\NOTEBOOKS_2025\aprilmay2025\newnotebooks\results.csv")
    p_indx += 1
# Out:
# __________________________________________________
# __________________________________________________
# __________________________________________________
# params set: 1
# __________________________________________________
# __________________________________________________
# __________________________________________________
# Running with params: {'num_heads': 2, 'num_transformer_blocks': 2, 'learning_rate': 2.782228330205127e-05, 'optimizer': 'Adam', 'weight_decay': 1.89223276202094e-06, 'batch_size': 10, 'label_smoothing': 0.17}
# __________________________________________________
# __________________________________________________
# __________________________________________________
# Fold No: 1
# Epoch [1/100], Loss: 0.6909, Accuracy: 0.5362
# Validation Loss: 0.7481, Validation Accuracy: 0.5889
# Epoch [2/100], Loss: 0.6535, Accuracy: 0.6749
# Validation Loss: 0.6654, Validation Accuracy: 0.6288
# Epoch [3/100], Loss: 0.6126, Accuracy: 0.7374
# Validation Loss: 0.6415, Validation Accuracy: 0.6818
# Epoch [4/100], Loss: 0.5919, Accuracy: 0.7844
# Validation Loss: 0.7022, Validation Accuracy: 0.6667
# Epoch [5/100], Loss: 0.5847, Accuracy: 0.7988
# Validation Loss: 0.5851, Validation Accuracy: 0.6802
# Epoch [6/100], Loss: 0.5796, Accuracy: 0.7967
# Validation Loss: 0.6099, Validation Accuracy: 0.6982
# Epoch [7/100], Loss: 0.5753, Accuracy: 0.8053
# Validation Loss: 0.5985, Validation Accuracy: 0.7072
# Epoch [8/100], Loss: 0.5644, Accuracy: 0.8251
# Validation Loss: 0.6121, Validation Accuracy: 0.7042
# Epoch [9/100], Loss: 0.5683, Accuracy: 0.8181
# Validation Loss: 0.5799, Validation Accuracy: 0.7111
# Epoch [10/100], Loss: 0.5596, Accuracy: 0.8292
# Validation Loss: 0.5806, Validation Accuracy: 0.7078
# Epoch [11/100], Loss: 0.5560, Accuracy: 0.8346
# Validation Loss: 0.5781, Validation Accuracy: 0.7066
# Epoch [12/100], Loss: 0.5545, Accuracy: 0.8317
# Validation Loss: 0.6154, Validation Accuracy: 0.7229
# Epoch [13/100], Loss: 0.5540, Accuracy: 0.8325
# Validation Loss: 0.5681, Validation Accuracy: 0.7079
# Epoch [14/100], Loss: 0.5474, Accuracy: 0.8473
# Validation Loss: 0.5929, Validation Accuracy: 0.7121
# Epoch [15/100], Loss: 0.5428, Accuracy: 0.8531
# Validation Loss: 0.5722, Validation Accuracy: 0.7194
# Epoch [16/100], Loss: 0.5431, Accuracy: 0.8547
# Validation Loss: 0.5834, Validation Accuracy: 0.7328
# Epoch [17/100], Loss: 0.5394, Accuracy: 0.8551
# Validation Loss: 0.6005, Validation Accuracy: 0.7345
# Epoch [18/100], Loss: 0.5343, Accuracy: 0.8704
# Validation Loss: 0.6165, Validation Accuracy: 0.7379
# Epoch [19/100], Loss: 0.5340, Accuracy: 0.8679
# Validation Loss: 0.5820, Validation Accuracy: 0.7316
# Epoch [20/100], Loss: 0.5328, Accuracy: 0.8675
# Validation Loss: 0.6038, Validation Accuracy: 0.7354
# Epoch [21/100], Loss: 0.5277, Accuracy: 0.8757
# Validation Loss: 0.5756, Validation Accuracy: 0.7115
# Epoch [22/100], Loss: 0.5258, Accuracy: 0.8782
# Validation Loss: 0.5937, Validation Accuracy: 0.7306
# Epoch [23/100], Loss: 0.5213, Accuracy: 0.8889
# Validation Loss: 0.6054, Validation Accuracy: 0.7295
# Divergence detected. Stopping training after 10 epochs.
# Early stopping
# Test Fold 1, Mean AUPRC: 0.7237, Balanced Accuracy: 0.7607
# Class-wise Accuracy:
# Class 0: 709/849 (83.51%)
# Class 1: 232/338 (68.64%)
#
# Precision-Recall Curve:
# ROC Curve:
# Mean F1 Score: 0.7528
# Balanced Accuracy: 0.7607
# Average AUPRC: 0.7237
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85       849
#            1       0.62      0.69      0.65       338
#
#     accuracy                           0.79      1187
#    macro avg       0.75      0.76      0.75      1187
# weighted avg       0.80      0.79      0.80      1187
#
# __________________________________________________
# __________________________________________________
# __________________________________________________
# Fold No: 2
# Epoch [1/100], Loss: 0.6918, Accuracy: 0.5238
# Validation Loss: 0.6867, Validation Accuracy: 0.5426
# Epoch [2/100], Loss: 0.6594, Accuracy: 0.6884
# Validation Loss: 0.6355, Validation Accuracy: 0.6124
# Epoch [3/100], Loss: 0.6105, Accuracy: 0.7540
# Validation Loss: 0.6021, Validation Accuracy: 0.6890
# Epoch [4/100], Loss: 0.5939, Accuracy: 0.7751
# Validation Loss: 0.6018, Validation Accuracy: 0.7250
# Epoch [5/100], Loss: 0.5896, Accuracy: 0.7799
# Validation Loss: 0.5994, Validation Accuracy: 0.7439
# Epoch [6/100], Loss: 0.5883, Accuracy: 0.7815
# Validation Loss: 0.6150, Validation Accuracy: 0.7512
# Epoch [7/100], Loss: 0.5804, Accuracy: 0.8026
# Validation Loss: 0.5842, Validation Accuracy: 0.7492
# Epoch [8/100], Loss: 0.5771, Accuracy: 0.8058
# Validation Loss: 0.5840, Validation Accuracy: 0.7462
# Epoch [9/100], Loss: 0.5685, Accuracy: 0.8132
# Validation Loss: 0.6050, Validation Accuracy: 0.7538
# Epoch [10/100], Loss: 0.5703, Accuracy: 0.8138
# Validation Loss: 0.5851, Validation Accuracy: 0.7438
# Epoch [11/100], Loss: 0.5696, Accuracy: 0.8212
# Validation Loss: 0.5989, Validation Accuracy: 0.7644
# Epoch [12/100], Loss: 0.5609, Accuracy: 0.8354
# Validation Loss: 0.5787, Validation Accuracy: 0.7450
# Epoch [13/100], Loss: 0.5614, Accuracy: 0.8360
# Validation Loss: 0.5980, Validation Accuracy: 0.7683
# Epoch [14/100], Loss: 0.5587, Accuracy: 0.8296
# Validation Loss: 0.5812, Validation Accuracy: 0.7435
# Epoch [15/100], Loss: 0.5541, Accuracy: 0.8492
# Validation Loss: 0.5861, Validation Accuracy: 0.7524
# Epoch [16/100], Loss: 0.5499, Accuracy: 0.8503
# Validation Loss: 0.5854, Validation Accuracy: 0.7551
# Epoch [17/100], Loss: 0.5484, Accuracy: 0.8471
# Validation Loss: 0.6192, Validation Accuracy: 0.7628
# Epoch [18/100], Loss: 0.5468, Accuracy: 0.8450
# Validation Loss: 0.5878, Validation Accuracy: 0.7516
# Epoch [19/100], Loss: 0.5496, Accuracy: 0.8481
# Validation Loss: 0.5981, Validation Accuracy: 0.7605
# Epoch [20/100], Loss: 0.5447, Accuracy: 0.8646
# Validation Loss: 0.5860, Validation Accuracy: 0.7634
# Epoch [21/100], Loss: 0.5376, Accuracy: 0.8693
# Validation Loss: 0.5887, Validation Accuracy: 0.7358
# Epoch [22/100], Loss: 0.5440, Accuracy: 0.8529
# Validation Loss: 0.5876, Validation Accuracy: 0.7278
# Divergence detected. Stopping training after 10 epochs.
# Early stopping
# Test Fold 2, Mean AUPRC: 0.7861, Balanced Accuracy: 0.7654
# Class-wise Accuracy:
# Class 0: 615/729 (84.36%)
# Class 1: 325/473 (68.71%)
#
# Precision-Recall Curve:
# ROC Curve:
# Mean F1 Score: 0.7686
# Balanced Accuracy: 0.7654
# Average AUPRC: 0.7861
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82       729
#            1       0.74      0.69      0.71       473
#
#     accuracy                           0.78      1202
#    macro avg       0.77      0.77      0.77      1202
# weighted avg       0.78      0.78      0.78      1202
#
# __________________________________________________
# __________________________________________________
# __________________________________________________
# Fold No: 3
# Epoch [1/100], Loss: 0.6932, Accuracy: 0.5345
# Validation Loss: 0.6884, Validation Accuracy: 0.5822
# Epoch [2/100], Loss: 0.6707, Accuracy: 0.6329
# Validation Loss: 0.6389, Validation Accuracy: 0.7578
# Epoch [3/100], Loss: 0.6343, Accuracy: 0.7108
# Validation Loss: 0.6110, Validation Accuracy: 0.7868
# Epoch [4/100], Loss: 0.6140, Accuracy: 0.7433
# Validation Loss: 0.5953, Validation Accuracy: 0.7816
# Epoch [5/100], Loss: 0.6000, Accuracy: 0.7637
# Validation Loss: 0.5871, Validation Accuracy: 0.7778
# Epoch [6/100], Loss: 0.5909, Accuracy: 0.7857
# Validation Loss: 0.5928, Validation Accuracy: 0.7955
# Epoch [7/100], Loss: 0.5871, Accuracy: 0.7962
# Validation Loss: 0.5998, Validation Accuracy: 0.7775
# Epoch [8/100], Loss: 0.5829, Accuracy: 0.7962
# Validation Loss: 0.5881, Validation Accuracy: 0.7726
# Epoch [9/100], Loss: 0.5755, Accuracy: 0.8097
# Validation Loss: 0.5878, Validation Accuracy: 0.7671
# Epoch [10/100], Loss: 0.5800, Accuracy: 0.7967
# Validation Loss: 0.5909, Validation Accuracy: 0.7423
# Epoch [11/100], Loss: 0.5666, Accuracy: 0.8212
# Validation Loss: 0.5934, Validation Accuracy: 0.7684
# Epoch [12/100], Loss: 0.5687, Accuracy: 0.8182
# Validation Loss: 0.5899, Validation Accuracy: 0.7451
# Epoch [13/100], Loss: 0.5637, Accuracy: 0.8282
# Validation Loss: 0.5888, Validation Accuracy: 0.7496
# Epoch [14/100], Loss: 0.5610, Accuracy: 0.8297
# Validation Loss: 0.6011, Validation Accuracy: 0.7750
# Epoch [15/100], Loss: 0.5564, Accuracy: 0.8372
# Validation Loss: 0.5855, Validation Accuracy: 0.7832
# Epoch [16/100], Loss: 0.5568, Accuracy: 0.8302
# Validation Loss: 0.5813, Validation Accuracy: 0.7708
# Epoch [17/100], Loss: 0.5528, Accuracy: 0.8427
# Validation Loss: 0.5930, Validation Accuracy: 0.7921
# Epoch [18/100], Loss: 0.5491, Accuracy: 0.8427
# Validation Loss: 0.5873, Validation Accuracy: 0.7631
# Epoch [19/100], Loss: 0.5474, Accuracy: 0.8497
# Validation Loss: 0.5814, Validation Accuracy: 0.7816
# Epoch [20/100], Loss: 0.5477, Accuracy: 0.8462
# Validation Loss: 0.5802, Validation Accuracy: 0.7751
# Epoch [21/100], Loss: 0.5426, Accuracy: 0.8531
# Validation Loss: 0.5841, Validation Accuracy: 0.7715
# Epoch [22/100], Loss: 0.5451, Accuracy: 0.8477
# Validation Loss: 0.5841, Validation Accuracy: 0.7683
# Epoch [23/100], Loss: 0.5413, Accuracy: 0.8511
# Validation Loss: 0.5845, Validation Accuracy: 0.7637
# Epoch [24/100], Loss: 0.5383, Accuracy: 0.8676
# Validation Loss: 0.5884, Validation Accuracy: 0.7763
# Epoch [25/100], Loss: 0.5348, Accuracy: 0.8731
# Validation Loss: 0.5929, Validation Accuracy: 0.7467
# Epoch [26/100], Loss: 0.5326, Accuracy: 0.8736
# Validation Loss: 0.5819, Validation Accuracy: 0.7770
# Epoch [27/100], Loss: 0.5292, Accuracy: 0.8691
# Validation Loss: 0.5885, Validation Accuracy: 0.7514
# Epoch [28/100], Loss: 0.5318, Accuracy: 0.8736
# Validation Loss: 0.5841, Validation Accuracy: 0.7707
# Epoch [29/100], Loss: 0.5268, Accuracy: 0.8771
# Validation Loss: 0.5877, Validation Accuracy: 0.7622
# Epoch [30/100], Loss: 0.5283, Accuracy: 0.8666
# Validation Loss: 0.5825, Validation Accuracy: 0.7850
# Divergence detected. Stopping training after 10 epochs.
# Early stopping
# Test Fold 3, Mean AUPRC: 0.7740, Balanced Accuracy: 0.7896
# Class-wise Accuracy:
# Class 0: 610/760 (80.26%)
# Class 1: 219/282 (77.66%)
#
# Precision-Recall Curve:
# ROC Curve:
# Mean F1 Score: 0.7621
# Balanced Accuracy: 0.7896
# Average AUPRC: 0.7740
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.80      0.85       760
#            1       0.59      0.78      0.67       282
#
#     accuracy                           0.80      1042
#    macro avg       0.75      0.79      0.76      1042
# weighted avg       0.82      0.80      0.80      1042
#
# __________________________________________________
# __________________________________________________
# __________________________________________________
# Fold No: 4
# Epoch [1/100], Loss: 0.6837, Accuracy: 0.5784
# Validation Loss: 0.6866, Validation Accuracy: 0.5711
# Epoch [2/100], Loss: 0.6514, Accuracy: 0.6741
# Validation Loss: 0.6703, Validation Accuracy: 0.6405
# Epoch [3/100], Loss: 0.6356, Accuracy: 0.7061
# Validation Loss: 0.6653, Validation Accuracy: 0.6844
# Epoch [4/100], Loss: 0.6151, Accuracy: 0.7475
# Validation Loss: 0.6648, Validation Accuracy: 0.6794
# Epoch [5/100], Loss: 0.6035, Accuracy: 0.7530
# Validation Loss: 0.6137, Validation Accuracy: 0.6935
# Epoch [6/100], Loss: 0.5920, Accuracy: 0.7806
# Validation Loss: 0.6658, Validation Accuracy: 0.7152
# Epoch [7/100], Loss: 0.5877, Accuracy: 0.7890
# Validation Loss: 0.6585, Validation Accuracy: 0.7039
# Epoch [8/100], Loss: 0.5778, Accuracy: 0.7968
# Validation Loss: 0.6347, Validation Accuracy: 0.7122
# Epoch [9/100], Loss: 0.5784, Accuracy: 0.7983
# Validation Loss: 0.6142, Validation Accuracy: 0.7252
# Epoch [10/100], Loss: 0.5783, Accuracy: 0.8003
# Validation Loss: 0.6405, Validation Accuracy: 0.7190
# Epoch [11/100], Loss: 0.5744, Accuracy: 0.8087
# Validation Loss: 0.6270, Validation Accuracy: 0.7176
# Epoch [12/100], Loss: 0.5637, Accuracy: 0.8289
# Validation Loss: 0.6317, Validation Accuracy: 0.7107
# Epoch [13/100], Loss: 0.5669, Accuracy: 0.8250
# Validation Loss: 0.6224, Validation Accuracy: 0.7239
# Epoch [14/100], Loss: 0.5605, Accuracy: 0.8279
# Validation Loss: 0.5997, Validation Accuracy: 0.7552
# Epoch [15/100], Loss: 0.5559, Accuracy: 0.8407
# Validation Loss: 0.6781, Validation Accuracy: 0.7109
# Epoch [16/100], Loss: 0.5562, Accuracy: 0.8328
# Validation Loss: 0.5908, Validation Accuracy: 0.7404
# Epoch [17/100], Loss: 0.5552, Accuracy: 0.8333
# Validation Loss: 0.6875, Validation Accuracy: 0.7032
# Epoch [18/100], Loss: 0.5571, Accuracy: 0.8368
# Validation Loss: 0.6135, Validation Accuracy: 0.7339
# Epoch [19/100], Loss: 0.5529, Accuracy: 0.8447
# Validation Loss: 0.6327, Validation Accuracy: 0.7355
# Epoch [20/100], Loss: 0.5488, Accuracy: 0.8407
# Validation Loss: 0.6935, Validation Accuracy: 0.7121
# Epoch [21/100], Loss: 0.5490, Accuracy: 0.8417
# Validation Loss: 0.6444, Validation Accuracy: 0.7314
# Epoch [22/100], Loss: 0.5434, Accuracy: 0.8550
# Validation Loss: 0.6225, Validation Accuracy: 0.7390
# Epoch [23/100], Loss: 0.5434, Accuracy: 0.8526
# Validation Loss: 0.5860, Validation Accuracy: 0.7380
# Epoch [24/100], Loss: 0.5389, Accuracy: 0.8580
# Validation Loss: 0.6088, Validation Accuracy: 0.7439
# Epoch [25/100], Loss: 0.5387, Accuracy: 0.8624
# Validation Loss: 0.5898, Validation Accuracy: 0.7644
# Epoch [26/100], Loss: 0.5289, Accuracy: 0.8708
# Validation Loss: 0.6119, Validation Accuracy: 0.7541
# Epoch [27/100], Loss: 0.5360, Accuracy: 0.8600
# Validation Loss: 0.6116, Validation Accuracy: 0.7481
# Epoch [28/100], Loss: 0.5293, Accuracy: 0.8728
# Validation Loss: 0.6296, Validation Accuracy: 0.7514
# Epoch [29/100], Loss: 0.5349, Accuracy: 0.8585
# Validation Loss: 0.6089, Validation Accuracy: 0.7561
# Epoch [30/100], Loss: 0.5287, Accuracy: 0.8708
# Validation Loss: 0.5924, Validation Accuracy: 0.7744
# Epoch [31/100], Loss: 0.5227, Accuracy: 0.8821
# Validation Loss: 0.6146, Validation Accuracy: 0.7542
# Epoch [32/100], Loss: 0.5209, Accuracy: 0.8861
# Validation Loss: 0.5943, Validation Accuracy: 0.7678
# Epoch [33/100], Loss: 0.5211, Accuracy: 0.8905
# Validation Loss: 0.5948, Validation Accuracy: 0.7663
# Divergence detected. Stopping training after 10 epochs.
# Early stopping
# Test Fold 4, Mean AUPRC: 0.8647, Balanced Accuracy: 0.8228
# Class-wise Accuracy:
# Class 0: 641/778 (82.39%)
# Class 1: 378/460 (82.17%)
#
# Precision-Recall Curve:
# ROC Curve:
# Mean F1 Score: 0.8147
# Balanced Accuracy: 0.8228
# Average AUPRC: 0.8647
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85       778
#            1       0.73      0.82      0.78       460
#
#     accuracy                           0.82      1238
#    macro avg       0.81      0.82      0.81      1238
# weighted avg       0.83      0.82      0.82      1238
#
# __________________________________________________
# __________________________________________________
# __________________________________________________
# Fold No: 5
# Epoch [1/100], Loss: 0.6885, Accuracy: 0.5663
# Validation Loss: 0.6869, Validation Accuracy: 0.6020
# Epoch [2/100], Loss: 0.6481, Accuracy: 0.6930
# Validation Loss: 0.6063, Validation Accuracy: 0.7700
# Epoch [3/100], Loss: 0.6108, Accuracy: 0.7507
# Validation Loss: 0.6195, Validation Accuracy: 0.7687
# Epoch [4/100], Loss: 0.5939, Accuracy: 0.7731
# Validation Loss: 0.5808, Validation Accuracy: 0.7741
# Epoch [5/100], Loss: 0.5915, Accuracy: 0.7772
# Validation Loss: 0.5983, Validation Accuracy: 0.7734
# Epoch [6/100], Loss: 0.5870, Accuracy: 0.7919
# Validation Loss: 0.5759, Validation Accuracy: 0.7845
# Epoch [7/100], Loss: 0.5839, Accuracy: 0.7969
# Validation Loss: 0.5885, Validation Accuracy: 0.7842
# Epoch [8/100], Loss: 0.5813, Accuracy: 0.7932
# Validation Loss: 0.5762, Validation Accuracy: 0.7994
# Epoch [9/100], Loss: 0.5736, Accuracy: 0.8056
# Validation Loss: 0.5744, Validation Accuracy: 0.7946
# Epoch [10/100], Loss: 0.5721, Accuracy: 0.8065
# Validation Loss: 0.5708, Validation Accuracy: 0.7821
# Epoch [11/100], Loss: 0.5662, Accuracy: 0.8166
# Validation Loss: 0.5784, Validation Accuracy: 0.7947
# Epoch [12/100], Loss: 0.5687, Accuracy: 0.8065
# Validation Loss: 0.5818, Validation Accuracy: 0.8029
# Epoch [13/100], Loss: 0.5605, Accuracy: 0.8253
# Validation Loss: 0.5867, Validation Accuracy: 0.8076
# Epoch [14/100], Loss: 0.5609, Accuracy: 0.8257
# Validation Loss: 0.5870, Validation Accuracy: 0.8010
# Epoch [15/100], Loss: 0.5618, Accuracy: 0.8289
# Validation Loss: 0.5850, Validation Accuracy: 0.8078
# Epoch [16/100], Loss: 0.5566, Accuracy: 0.8326
# Validation Loss: 0.5780, Validation Accuracy: 0.7912
# Epoch [17/100], Loss: 0.5584, Accuracy: 0.8262
# Validation Loss: 0.5642, Validation Accuracy: 0.8055
# Epoch [18/100], Loss: 0.5578, Accuracy: 0.8243
# Validation Loss: 0.5811, Validation Accuracy: 0.8141
# Epoch [19/100], Loss: 0.5520, Accuracy: 0.8358
# Validation Loss: 0.5602, Validation Accuracy: 0.8091
# Epoch [20/100], Loss: 0.5459, Accuracy: 0.8477
# Validation Loss: 0.5654, Validation Accuracy: 0.8008
# Epoch [21/100], Loss: 0.5433, Accuracy: 0.8504
# Validation Loss: 0.5835, Validation Accuracy: 0.8047
# Epoch [22/100], Loss: 0.5408, Accuracy: 0.8586
# Validation Loss: 0.5664, Validation Accuracy: 0.8062
# Epoch [23/100], Loss: 0.5371, Accuracy: 0.8609
# Validation Loss: 0.5928, Validation Accuracy: 0.7989
# Epoch [24/100], Loss: 0.5360, Accuracy: 0.8600
# Validation Loss: 0.5742, Validation Accuracy: 0.8113
# Epoch [25/100], Loss: 0.5400, Accuracy: 0.8614
# Validation Loss: 0.5835, Validation Accuracy: 0.8126
# Epoch [26/100], Loss: 0.5345, Accuracy: 0.8655
# Validation Loss: 0.5658, Validation Accuracy: 0.8099
# Epoch [27/100], Loss: 0.5296, Accuracy: 0.8728
# Validation Loss: 0.5922, Validation Accuracy: 0.8094
# Epoch [28/100], Loss: 0.5296, Accuracy: 0.8728
# Validation Loss: 0.5617, Validation Accuracy: 0.8002
# Epoch [29/100], Loss: 0.5297, Accuracy: 0.8728
# Validation Loss: 0.5689, Validation Accuracy: 0.8164
# Divergence detected. Stopping training after 10 epochs.
# Early stopping
# Test Fold 5, Mean AUPRC: 0.6146, Balanced Accuracy: 0.7571
# Class-wise Accuracy:
# Class 0: 788/950 (82.95%)
# Class 1: 139/203 (68.47%)
#
# Precision-Recall Curve:
# ROC Curve:
# Mean F1 Score: 0.7131
# Balanced Accuracy: 0.7571
# Average AUPRC: 0.6146
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87       950
#            1       0.46      0.68      0.55       203
#
#     accuracy                           0.80      1153
#    macro avg       0.69      0.76      0.71      1153
# weighted avg       0.84      0.80      0.82      1153
#
# Accuracy for each fold: [np.float64(0.7607453251650045), np.float64(0.7653624966286465), np.float64(0.7896136618141097), np.float64(0.822823292723818), np.float64(0.7571013741249677)]
# AUPRC for each fold: [np.float64(0.7236702244454664), np.float64(0.786126351802783), np.float64(0.7740279236160095), np.float64(0.8647124845546761), np.float64(0.6145632547767031)]
# Average AUPRC across all folds: 0.7526200478391276
# Average Balanced Accuracy across all folds: 0.7791292300913094
# Results saved to D:\PYTHONIG\newwindow\NOTEBOOKS_2025\aprilmay2025\newnotebooks\results.csv
# __________________________________________________
# __________________________________________________
# __________________________________________________
# params set: 2
# __________________________________________________
# __________________________________________________
# __________________________________________________
# Running with params: {'num_heads': 2, 'num_transformer_blocks': 4, 'learning_rate': 1.2292958406478385e-05, 'optimizer': 'Adam', 'weight_decay': 5.221031733062504e-06, 'batch_size': 32, 'label_smoothing': 0.16}
# __________________________________________________
# __________________________________________________
# __________________________________________________
# Fold No: 1
# Epoch [1/100], Loss: 0.6938, Accuracy: 0.5337
# Validation Loss: 0.6578, Validation Accuracy: 0.5040
# Epoch [2/100], Loss: 0.6906, Accuracy: 0.5272
# Validation Loss: 0.6791, Validation Accuracy: 0.5489
# Epoch [3/100], Loss: 0.6845, Accuracy: 0.6091
# Validation Loss: 0.6825, Validation Accuracy: 0.5909
# Epoch [4/100], Loss: 0.6768, Accuracy: 0.6514
# Validation Loss: 0.6517, Validation Accuracy: 0.5817
# Epoch [5/100], Loss: 0.6647, Accuracy: 0.6786
# Validation Loss: 0.6584, Validation Accuracy: 0.6388
# Epoch [6/100], Loss: 0.6537, Accuracy: 0.7008
# Validation Loss: 0.6358, Validation Accuracy: 0.6628
# Epoch [7/100], Loss: 0.6350, Accuracy: 0.7305
# Validation Loss: 0.6343, Validation Accuracy: 0.6651
# Epoch [8/100], Loss: 0.6231, Accuracy: 0.7391
# Validation Loss: 0.6101, Validation Accuracy: 0.6654
# Epoch [9/100], Loss: 0.6150, Accuracy: 0.7383
# Validation Loss: 0.6145, Validation Accuracy: 0.6811
# Epoch [10/100], Loss: 0.6038, Accuracy: 0.7601
# Validation Loss: 0.6192, Validation Accuracy: 0.6865
# Epoch [11/100], Loss: 0.5986, Accuracy: 0.7646
# Validation Loss: 0.5945, Validation Accuracy: 0.7013
# Epoch [12/100], Loss: 0.5912, Accuracy: 0.7761
# Validation Loss: 0.6016, Validation Accuracy: 0.7133
# Epoch [13/100], Loss: 0.5899, Accuracy: 0.7860
# Validation Loss: 0.5925, Validation Accuracy: 0.7119
# Epoch [14/100], Loss: 0.5832, Accuracy: 0.8000
# Validation Loss: 0.5896, Validation Accuracy: 0.7159
# Epoch [15/100], Loss: 0.5789, Accuracy: 0.8008
# Validation Loss: 0.5911, Validation Accuracy: 0.7226
# Epoch [16/100], Loss: 0.5795, Accuracy: 0.8058
# Validation Loss: 0.5761, Validation Accuracy: 0.7131
# Epoch [17/100], Loss: 0.5783, Accuracy: 0.8021
# Validation Loss: 0.5700, Validation Accuracy: 0.7139
# Epoch [18/100], Loss: 0.5733, Accuracy: 0.8160
# Validation Loss: 0.5835, Validation Accuracy: 0.7330
# Epoch [19/100], Loss: 0.5749, Accuracy: 0.8037
# Validation Loss: 0.5797, Validation Accuracy: 0.7302
# Epoch [20/100], Loss: 0.5733, Accuracy: 0.8136
# Validation Loss: 0.5752, Validation Accuracy: 0.7356
# Epoch [21/100], Loss: 0.5663, Accuracy: 0.8202
# Validation Loss: 0.5726, Validation Accuracy: 0.7308
# Epoch [22/100], Loss: 0.5702, Accuracy: 0.8165
# Validation Loss: 0.5652, Validation Accuracy: 0.7393
# Epoch [23/100], Loss: 0.5654, Accuracy: 0.8272
# Validation Loss: 0.5732, Validation Accuracy: 0.7391
# Epoch [24/100], Loss: 0.5620, Accuracy: 0.8288
# Validation Loss: 0.5663, Validation Accuracy: 0.7289
# Epoch [25/100], Loss: 0.5646, Accuracy: 0.8267
# Validation Loss: 0.5870, Validation Accuracy: 0.7395
# Epoch [26/100], Loss: 0.5617, Accuracy: 0.8333
# Validation Loss: 0.5662, Validation Accuracy: 0.7306
# Epoch [27/100], Loss: 0.5603, Accuracy: 0.8399
# Validation Loss: 0.5742, Validation Accuracy: 0.7382
# Epoch [28/100], Loss: 0.5600, Accuracy: 0.8399
# Validation Loss: 0.6026, Validation Accuracy: 0.7332
# Epoch [29/100], Loss: 0.5573, Accuracy: 0.8416
# Validation Loss: 0.5604, Validation Accuracy: 0.7370
# Epoch [30/100], Loss: 0.5571, Accuracy: 0.8346
# Validation Loss: 0.5589, Validation Accuracy: 0.7285
# Epoch [31/100], Loss: 0.5549, Accuracy: 0.8469
# Validation Loss: 0.5673, Validation Accuracy: 0.7308
# Epoch [32/100], Loss: 0.5520, Accuracy: 0.8424
# Validation Loss: 0.5752, Validation Accuracy: 0.7453
# Epoch [33/100], Loss: 0.5543, Accuracy: 0.8403
# Validation Loss: 0.5799, Validation Accuracy: 0.7478
# Epoch [34/100], Loss: 0.5504, Accuracy: 0.8461
# Validation Loss: 0.5747, Validation Accuracy: 0.7453
# Epoch [35/100], Loss: 0.5543, Accuracy: 0.8428
# Validation Loss: 0.5681, Validation Accuracy: 0.7398
# Epoch [36/100], Loss: 0.5514, Accuracy: 0.8473
# Validation Loss: 0.5768, Validation Accuracy: 0.7425
# Epoch [37/100], Loss: 0.5529, Accuracy: 0.8407
# Validation Loss: 0.5804, Validation Accuracy: 0.7511
# Epoch [38/100], Loss: 0.5481, Accuracy: 0.8523
# Validation Loss: 0.5660, Validation Accuracy: 0.7416
# Epoch [39/100], Loss: 0.5486, Accuracy: 0.8506
# Validation Loss: 0.5888, Validation Accuracy: 0.7443
# Epoch [40/100], Loss: 0.5477, Accuracy: 0.8535
# Validation Loss: 0.5786, Validation Accuracy: 0.7469
# Divergence detected. Stopping training after 10 epochs.
# Early stopping
# Test Fold 1, Mean AUPRC: 0.7213, Balanced Accuracy: 0.7575
# Class-wise Accuracy:
# Class 0: 691/849 (81.39%)
# Class 1: 237/338 (70.12%)
#
# Precision-Recall Curve:
# ROC Curve:
# Mean F1 Score: 0.7444
# Balanced Accuracy: 0.7575
# Average AUPRC: 0.7213
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84       849
#            1       0.60      0.70      0.65       338
#
#     accuracy                           0.78      1187
#    macro avg       0.74      0.76      0.74      1187
# weighted avg       0.79      0.78      0.79      1187
#
# __________________________________________________
# __________________________________________________
# __________________________________________________
# Fold No: 2
# Epoch [1/100], Loss: 0.6943, Accuracy: 0.5423
# Validation Loss: 0.6720, Validation Accuracy: 0.5060
# Epoch [2/100], Loss: 0.6883, Accuracy: 0.5624
# Validation Loss: 0.6792, Validation Accuracy: 0.5566
# Epoch [3/100], Loss: 0.6853, Accuracy: 0.5968
# Validation Loss: 0.6706, Validation Accuracy: 0.5642
# Epoch [4/100], Loss: 0.6807, Accuracy: 0.6169
# Validation Loss: 0.6962, Validation Accuracy: 0.5745
# Epoch [5/100], Loss: 0.6769, Accuracy: 0.6312
# Validation Loss: 0.6790, Validation Accuracy: 0.5992
# Epoch [6/100], Loss: 0.6672, Accuracy: 0.6534
# Validation Loss: 0.6633, Validation Accuracy: 0.5898
# Epoch [7/100], Loss: 0.6629, Accuracy: 0.6730
# Validation Loss: 0.6620, Validation Accuracy: 0.6108
# Epoch [8/100], Loss: 0.6512, Accuracy: 0.7101
# Validation Loss: 0.6478, Validation Accuracy: 0.6086
# Epoch [9/100], Loss: 0.6393, Accuracy: 0.7243
# Validation Loss: 0.6490, Validation Accuracy: 0.6321
# Epoch [10/100], Loss: 0.6303, Accuracy: 0.7328
# Validation Loss: 0.6514, Validation Accuracy: 0.6603
# Epoch [11/100], Loss: 0.6160, Accuracy: 0.7534
# Validation Loss: 0.6349, Validation Accuracy: 0.6605
# Epoch [12/100], Loss: 0.6121, Accuracy: 0.7550
# Validation Loss: 0.6165, Validation Accuracy: 0.6382
# Epoch [13/100], Loss: 0.6012, Accuracy: 0.7667
# Validation Loss: 0.6263, Validation Accuracy: 0.7023
# Epoch [14/100], Loss: 0.6046, Accuracy: 0.7640
# Validation Loss: 0.6253, Validation Accuracy: 0.7112
# Epoch [15/100], Loss: 0.5983, Accuracy: 0.7608
# Validation Loss: 0.6132, Validation Accuracy: 0.6978
# Epoch [16/100], Loss: 0.5924, Accuracy: 0.7794
# Validation Loss: 0.6083, Validation Accuracy: 0.6936
# Epoch [17/100], Loss: 0.5942, Accuracy: 0.7714
# Validation Loss: 0.6099, Validation Accuracy: 0.7004
# Epoch [18/100], Loss: 0.5889, Accuracy: 0.7767
# Validation Loss: 0.6129, Validation Accuracy: 0.7076
# Epoch [19/100], Loss: 0.5872, Accuracy: 0.7778
# Validation Loss: 0.6087, Validation Accuracy: 0.7052
# Epoch [20/100], Loss: 0.5799, Accuracy: 0.7921
# Validation Loss: 0.6031, Validation Accuracy: 0.7010
# Epoch [21/100], Loss: 0.5903, Accuracy: 0.7720
# Validation Loss: 0.5992, Validation Accuracy: 0.7051
# Epoch [22/100], Loss: 0.5812, Accuracy: 0.7868
# Validation Loss: 0.5998, Validation Accuracy: 0.6983
# Epoch [23/100], Loss: 0.5748, Accuracy: 0.7979
# Validation Loss: 0.6042, Validation Accuracy: 0.7184
# Epoch [24/100], Loss: 0.5735, Accuracy: 0.8079
# Validation Loss: 0.5973, Validation Accuracy: 0.7027
# Epoch [25/100], Loss: 0.5787, Accuracy: 0.7984
# Validation Loss: 0.5949, Validation Accuracy: 0.7044
# Epoch [26/100], Loss: 0.5750, Accuracy: 0.8095
# Validation Loss: 0.6081, Validation Accuracy: 0.7212
# Epoch [27/100], Loss: 0.5764, Accuracy: 0.8053
# Validation Loss: 0.6008, Validation Accuracy: 0.7140
# Epoch [28/100], Loss: 0.5688, Accuracy: 0.8111
# Validation Loss: 0.6280, Validation Accuracy: 0.7274
# Epoch [29/100], Loss: 0.5733, Accuracy: 0.8085
# Validation Loss: 0.5961, Validation Accuracy: 0.7142
# Epoch [30/100], Loss: 0.5711, Accuracy: 0.8159
# Validation Loss: 0.5970, Validation Accuracy: 0.7365
# Epoch [31/100], Loss: 0.5673, Accuracy: 0.8185
# Validation Loss: 0.5952, Validation Accuracy: 0.7317
# Epoch [32/100], Loss: 0.5734, Accuracy: 0.8169
# Validation Loss: 0.6020, Validation Accuracy: 0.7371
# Epoch [33/100], Loss: 0.5668, Accuracy: 0.8132
# Validation Loss: 0.5979, Validation Accuracy: 0.7317
# Epoch [34/100], Loss: 0.5719, Accuracy: 0.8222
# Validation Loss: 0.5988, Validation Accuracy: 0.7306
# Epoch [35/100], Loss: 0.5626, Accuracy: 0.8296
# Validation Loss: 0.5941, Validation Accuracy: 0.7344
# Epoch [36/100], Loss: 0.5610, Accuracy: 0.8344
# Validation Loss: 0.6087, Validation Accuracy: 0.7301
# Epoch [37/100], Loss: 0.5593, Accuracy: 0.8370
# Validation Loss: 0.5927, Validation Accuracy: 0.7305
# Epoch [38/100], Loss: 0.5576, Accuracy: 0.8370
# Validation Loss: 0.5980, Validation Accuracy: 0.7398
# Epoch [39/100], Loss: 0.5558, Accuracy: 0.8471
# Validation Loss: 0.5931, Validation Accuracy: 0.7320
# Epoch [40/100], Loss: 0.5559, Accuracy: 0.8386
# Validation Loss: 0.5999, Validation Accuracy: 0.7356
# Epoch [41/100], Loss: 0.5560, Accuracy: 0.8392
# Validation Loss: 0.5943, Validation Accuracy: 0.7317
# Epoch [42/100], Loss: 0.5573, Accuracy: 0.8333
# Validation Loss: 0.5960, Validation Accuracy: 0.7385
# Epoch [43/100], Loss: 0.5574, Accuracy: 0.8529
# Validation Loss: 0.6079, Validation Accuracy: 0.7284
# Epoch [44/100], Loss: 0.5549, Accuracy: 0.8529
# Validation Loss: 0.5963, Validation Accuracy: 0.7406
# Epoch [45/100], Loss: 0.5527, Accuracy: 0.8455
# Validation Loss: 0.6009, Validation Accuracy: 0.7339
# Epoch [46/100], Loss: 0.5573, Accuracy: 0.8481
# Validation Loss: 0.5915, Validation Accuracy: 0.7287
# Epoch [47/100], Loss: 0.5499, Accuracy: 0.8471
# Validation Loss: 0.6001, Validation Accuracy: 0.7324
# Epoch [48/100], Loss: 0.5530, Accuracy: 0.8513
# Validation Loss: 0.5927, Validation Accuracy: 0.7350
# Epoch [49/100], Loss: 0.5458, Accuracy: 0.8519
# Validation Loss: 0.6018, Validation Accuracy: 0.7455
# Epoch [50/100], Loss: 0.5414, Accuracy: 0.8550
# Validation Loss: 0.5982, Validation Accuracy: 0.7389
# Epoch [51/100], Loss: 0.5491, Accuracy: 0.8487
# Validation Loss: 0.5988, Validation Accuracy: 0.7398
# Epoch [52/100], Loss: 0.5461, Accuracy: 0.8524
# Validation Loss: 0.5957, Validation Accuracy: 0.7451
# Epoch [53/100], Loss: 0.5496, Accuracy: 0.8455
# Validation Loss: 0.5909, Validation Accuracy: 0.7441
# Epoch [54/100], Loss: 0.5469, Accuracy: 0.8587
# Validation Loss: 0.5966, Validation Accuracy: 0.7531
# Epoch [55/100], Loss: 0.5405, Accuracy: 0.8667
# Validation Loss: 0.6106, Validation Accuracy: 0.7491
# Epoch [56/100], Loss: 0.5468, Accuracy: 0.8556
# Validation Loss: 0.5972, Validation Accuracy: 0.7377
# Epoch [57/100], Loss: 0.5417, Accuracy: 0.8519
# Validation Loss: 0.6118, Validation Accuracy: 0.7400
# Epoch [58/100], Loss: 0.5409, Accuracy: 0.8577
# Validation Loss: 0.5978, Validation Accuracy: 0.7345
# Epoch [59/100], Loss: 0.5398, Accuracy: 0.8582
# Validation Loss: 0.6048, Validation Accuracy: 0.7431
# Epoch [60/100], Loss: 0.5351, Accuracy: 0.8656
# Validation Loss: 0.5973, Validation Accuracy: 0.7404
# Epoch [61/100], Loss: 0.5378, Accuracy: 0.8624
# Validation Loss: 0.5967, Validation Accuracy: 0.7321
# Epoch [62/100], Loss: 0.5330, Accuracy: 0.8794
# Validation Loss: 0.6111, Validation Accuracy: 0.7411
# Epoch [63/100], Loss: 0.5389, Accuracy: 0.8709
# Validation Loss: 0.5982, Validation Accuracy: 0.7401
# Divergence detected. Stopping training after 10 epochs.
# Early stopping
# Test Fold 2, Mean AUPRC: 0.7427, Balanced Accuracy: 0.7257
# Class-wise Accuracy:
# Class 0: 628/729 (86.15%)
# Class 1: 279/473 (58.99%)
#
# Precision-Recall Curve:
# ROC Curve:
# Mean F1 Score: 0.7320
# Balanced Accuracy: 0.7257
# Average AUPRC: 0.7427
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81       729
#            1       0.73      0.59      0.65       473
#
#     accuracy                           0.75      1202
#    macro avg       0.75      0.73      0.73      1202
# weighted avg       0.75      0.75      0.75      1202
#
# __________________________________________________
# __________________________________________________
# __________________________________________________
# Fold No: 3
# Epoch [1/100], Loss: 0.7065, Accuracy: 0.5275
# Validation Loss: 0.6907, Validation Accuracy: 0.5398
# Epoch [2/100], Loss: 0.6893, Accuracy: 0.5674
# Validation Loss: 0.6972, Validation Accuracy: 0.5292
# Epoch [3/100], Loss: 0.6871, Accuracy: 0.5784
# Validation Loss: 0.6829, Validation Accuracy: 0.5818
# Epoch [4/100], Loss: 0.6801, Accuracy: 0.6244
# Validation Loss: 0.6747, Validation Accuracy: 0.5923
# Epoch [5/100], Loss: 0.6703, Accuracy: 0.6723
# Validation Loss: 0.6723, Validation Accuracy: 0.6624
# Epoch [6/100], Loss: 0.6571, Accuracy: 0.7053
# Validation Loss: 0.6627, Validation Accuracy: 0.6899
# Epoch [7/100], Loss: 0.6430, Accuracy: 0.7193
# Validation Loss: 0.6392, Validation Accuracy: 0.6840
# Epoch [8/100], Loss: 0.6279, Accuracy: 0.7353
# Validation Loss: 0.6299, Validation Accuracy: 0.7364
# Epoch [9/100], Loss: 0.6138, Accuracy: 0.7542
# Validation Loss: 0.6142, Validation Accuracy: 0.7345
# Epoch [10/100], Loss: 0.6053, Accuracy: 0.7587
# Validation Loss: 0.6085, Validation Accuracy: 0.7715
# Epoch [11/100], Loss: 0.6014, Accuracy: 0.7557
# Validation Loss: 0.5973, Validation Accuracy: 0.7529
# Epoch [12/100], Loss: 0.5946, Accuracy: 0.7767
# Validation Loss: 0.5928, Validation Accuracy: 0.7703
# Epoch [13/100], Loss: 0.5938, Accuracy: 0.7822
# Validation Loss: 0.5923, Validation Accuracy: 0.7764
# Epoch [14/100], Loss: 0.5869, Accuracy: 0.7887
# Validation Loss: 0.5900, Validation Accuracy: 0.7725
# Epoch [15/100], Loss: 0.5872, Accuracy: 0.7912
# Validation Loss: 0.5897, Validation Accuracy: 0.7860
# Epoch [16/100], Loss: 0.5851, Accuracy: 0.7797
# Validation Loss: 0.5927, Validation Accuracy: 0.7857
# Epoch [17/100], Loss: 0.5783, Accuracy: 0.8022
# Validation Loss: 0.5866, Validation Accuracy: 0.7741
# Epoch [18/100], Loss: 0.5789, Accuracy: 0.8017
# Validation Loss: 0.5858, Validation Accuracy: 0.7744
# Epoch [19/100], Loss: 0.5768, Accuracy: 0.8067
# Validation Loss: 0.5861, Validation Accuracy: 0.7730
# Epoch [20/100], Loss: 0.5737, Accuracy: 0.8132
# Validation Loss: 0.5873, Validation Accuracy: 0.7755
# Epoch [21/100], Loss: 0.5743, Accuracy: 0.8117
# Validation Loss: 0.5883, Validation Accuracy: 0.7742
# Epoch [22/100], Loss: 0.5714, Accuracy: 0.8137
# Validation Loss: 0.5877, Validation Accuracy: 0.7651
# Epoch [23/100], Loss: 0.5706, Accuracy: 0.8132
# Validation Loss: 0.5907, Validation Accuracy: 0.7776
# Epoch [24/100], Loss: 0.5690, Accuracy: 0.8187
# Validation Loss: 0.5875, Validation Accuracy: 0.7794
# Epoch [25/100], Loss: 0.5675, Accuracy: 0.8202
# Validation Loss: 0.5860, Validation Accuracy: 0.7705
# Epoch [26/100], Loss: 0.5662, Accuracy: 0.8172
# Validation Loss: 0.5852, Validation Accuracy: 0.7645
# Epoch [27/100], Loss: 0.5628, Accuracy: 0.8252
# Validation Loss: 0.5848, Validation Accuracy: 0.7712
# Epoch [28/100], Loss: 0.5627, Accuracy: 0.8227
# Validation Loss: 0.5873, Validation Accuracy: 0.7787
# Epoch [29/100], Loss: 0.5605, Accuracy: 0.8312
# Validation Loss: 0.5862, Validation Accuracy: 0.7863
# Epoch [30/100], Loss: 0.5618, Accuracy: 0.8307
# Validation Loss: 0.5878, Validation Accuracy: 0.7803
# Epoch [31/100], Loss: 0.5579, Accuracy: 0.8267
# Validation Loss: 0.5933, Validation Accuracy: 0.7732
# Epoch [32/100], Loss: 0.5580, Accuracy: 0.8322
# Validation Loss: 0.5925, Validation Accuracy: 0.7507
# Epoch [33/100], Loss: 0.5576, Accuracy: 0.8342
# Validation Loss: 0.5883, Validation Accuracy: 0.7854
# Epoch [34/100], Loss: 0.5563, Accuracy: 0.8377
# Validation Loss: 0.5892, Validation Accuracy: 0.7696
# Epoch [35/100], Loss: 0.5522, Accuracy: 0.8467
# Validation Loss: 0.5873, Validation Accuracy: 0.7706
# Epoch [36/100], Loss: 0.5518, Accuracy: 0.8442
# Validation Loss: 0.5885, Validation Accuracy: 0.7848
# Epoch [37/100], Loss: 0.5522, Accuracy: 0.8352
# Validation Loss: 0.5901, Validation Accuracy: 0.7798
# Divergence detected. Stopping training after 10 epochs.
# Early stopping
# Test Fold 3, Mean AUPRC: 0.7363, Balanced Accuracy: 0.7676
# Class-wise Accuracy:
# Class 0: 590/760 (77.63%)
# Class 1: 214/282 (75.89%)
#
# Precision-Recall Curve:
# ROC Curve:
# Mean F1 Score: 0.7374
# Balanced Accuracy: 0.7676
# Average AUPRC: 0.7363
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.83       760
#            1       0.56      0.76      0.64       282
#
#     accuracy                           0.77      1042
#    macro avg       0.73      0.77      0.74      1042
# weighted avg       0.80      0.77      0.78      1042
#
# __________________________________________________
# __________________________________________________
# __________________________________________________
# Fold No: 4
# Epoch [1/100], Loss: 0.6980, Accuracy: 0.4896
# Validation Loss: 0.7012, Validation Accuracy: 0.4828
# Epoch [2/100], Loss: 0.6914, Accuracy: 0.5192
# Validation Loss: 0.6897, Validation Accuracy: 0.4984
# Epoch [3/100], Loss: 0.6895, Accuracy: 0.5646
# Validation Loss: 0.6948, Validation Accuracy: 0.4915
# Epoch [4/100], Loss: 0.6874, Accuracy: 0.5804
# Validation Loss: 0.6983, Validation Accuracy: 0.5040
# Epoch [5/100], Loss: 0.6842, Accuracy: 0.5976
# Validation Loss: 0.6931, Validation Accuracy: 0.5201
# Epoch [6/100], Loss: 0.6836, Accuracy: 0.5779
# Validation Loss: 0.6913, Validation Accuracy: 0.5112
# Epoch [7/100], Loss: 0.6795, Accuracy: 0.6085
# Validation Loss: 0.6909, Validation Accuracy: 0.5292
# Epoch [8/100], Loss: 0.6772, Accuracy: 0.6105
# Validation Loss: 0.6807, Validation Accuracy: 0.5262
# Epoch [9/100], Loss: 0.6721, Accuracy: 0.6262
# Validation Loss: 0.6635, Validation Accuracy: 0.4817
# Epoch [10/100], Loss: 0.6693, Accuracy: 0.6238
# Validation Loss: 0.6820, Validation Accuracy: 0.5384
# Epoch [11/100], Loss: 0.6634, Accuracy: 0.6425
# Validation Loss: 0.6928, Validation Accuracy: 0.5606
# Epoch [12/100], Loss: 0.6605, Accuracy: 0.6445
# Validation Loss: 0.6779, Validation Accuracy: 0.5338
# Epoch [13/100], Loss: 0.6541, Accuracy: 0.6716
# Validation Loss: 0.6795, Validation Accuracy: 0.5611
# Epoch [14/100], Loss: 0.6456, Accuracy: 0.6864
# Validation Loss: 0.6953, Validation Accuracy: 0.5930
# Epoch [15/100], Loss: 0.6444, Accuracy: 0.6834
# Validation Loss: 0.6904, Validation Accuracy: 0.6024
# Epoch [16/100], Loss: 0.6420, Accuracy: 0.6854
# Validation Loss: 0.6694, Validation Accuracy: 0.5812
# Epoch [17/100], Loss: 0.6347, Accuracy: 0.7061
# Validation Loss: 0.6687, Validation Accuracy: 0.6276
# Epoch [18/100], Loss: 0.6312, Accuracy: 0.7081
# Validation Loss: 0.6619, Validation Accuracy: 0.6347
# Epoch [19/100], Loss: 0.6216, Accuracy: 0.7224
# Validation Loss: 0.6610, Validation Accuracy: 0.6780
# Epoch [20/100], Loss: 0.6109, Accuracy: 0.7465
# Validation Loss: 0.6291, Validation Accuracy: 0.6654
# Epoch [21/100], Loss: 0.6074, Accuracy: 0.7490
# Validation Loss: 0.6558, Validation Accuracy: 0.6995
# Epoch [22/100], Loss: 0.5999, Accuracy: 0.7697
# Validation Loss: 0.6425, Validation Accuracy: 0.7153
# Epoch [23/100], Loss: 0.5910, Accuracy: 0.7855
# Validation Loss: 0.6195, Validation Accuracy: 0.7049
# Epoch [24/100], Loss: 0.5854, Accuracy: 0.7899
# Validation Loss: 0.6230, Validation Accuracy: 0.7145
# Epoch [25/100], Loss: 0.5848, Accuracy: 0.7924
# Validation Loss: 0.6202, Validation Accuracy: 0.7190
# Epoch [26/100], Loss: 0.5774, Accuracy: 0.8062
# Validation Loss: 0.6315, Validation Accuracy: 0.7118
# Epoch [27/100], Loss: 0.5769, Accuracy: 0.8052
# Validation Loss: 0.6178, Validation Accuracy: 0.7119
# Epoch [28/100], Loss: 0.5742, Accuracy: 0.8072
# Validation Loss: 0.6234, Validation Accuracy: 0.7233
# Epoch [29/100], Loss: 0.5791, Accuracy: 0.7998
# Validation Loss: 0.6098, Validation Accuracy: 0.7150
# Epoch [30/100], Loss: 0.5692, Accuracy: 0.8250
# Validation Loss: 0.6201, Validation Accuracy: 0.7210
# Epoch [31/100], Loss: 0.5719, Accuracy: 0.8161
# Validation Loss: 0.6318, Validation Accuracy: 0.7123
# Epoch [32/100], Loss: 0.5670, Accuracy: 0.8200
# Validation Loss: 0.6092, Validation Accuracy: 0.7257
# Epoch [33/100], Loss: 0.5610, Accuracy: 0.8245
# Validation Loss: 0.6001, Validation Accuracy: 0.7409
# Epoch [34/100], Loss: 0.5641, Accuracy: 0.8230
# Validation Loss: 0.6120, Validation Accuracy: 0.7157
# Epoch [35/100], Loss: 0.5628, Accuracy: 0.8240
# Validation Loss: 0.6358, Validation Accuracy: 0.7259
